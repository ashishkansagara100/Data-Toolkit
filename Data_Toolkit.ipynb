# %%
#1 How do you create a 2D NumPy array and calculate the sum of each row)

import numpy as np

a = np.array([[1,2,3],
              [4,5,6]])

print(a.sum(axis=1))

# %%
#2 Write a Pandas script to find the mean of a specific column in a DataFrameA

import pandas as pd

df = pd.DataFrame({
    "marks":[80,90,70]
})

print(df["marks"].mean())

# %%
#3 Create a scatter plot using Matplotlib

import matplotlib.pyplot as plt

x = [1,2,3,4]
y = [10,20,15,25]

plt.scatter(x,y)
plt.show()

# %%
#4 How do you calculate the correlation matrix using Seaborn and visualize it with a heatmap)

import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

df = pd.DataFrame({
    "a":[1,2,3],
    "b":[2,4,6],
    "c":[3,6,9]
})

sns.heatmap(df.corr(), annot=True)
plt.show()

# %%
#5 Generate a bar plot using PlotlyA

import plotly.express as px

x = ["A","B","C"]
y = [10,20,15]

fig = px.bar(x=x, y=y)
fig.show()

# %%
#6 Create a DataFrame and add a new column based on an existing column

import pandas as pd

df = pd.DataFrame({"num":[1,2,3]})

df["square"] = df["num"] * df["num"]

print(df)

# %%
#7 Write a program to perform element-wise multiplicaimport numpy as np

a = np.array([1,2,3])
b = np.array([4,5,6])

print(a * b)

# %%
#8 Create a line plot with multiple lines using Matplotlib
import matplotlib.pyplot as plt

x = [1,2,3,4]

y1 = [1,2,3,4]
y2 = [4,3,2,1]

plt.plot(x, y1)
plt.plot(x, y2)
plt.show()

# %%
#9 Generate a Pandas DataFrame and filter rows where a column value is greater than a thresholdA

import pandas as pd

df = pd.DataFrame({
    "marks":[50,80,90,30]
})

print(df[df["marks"] > 60])

# %%
#10 Create a histogram using Seaborn to visualize a distribution

import seaborn as sns
import matplotlib.pyplot as plt

data = [1,2,2,3,3,3,4,5]

sns.histplot(data)
plt.show()

# %%
#11Perform matrix multiplication using NumPyA

import numpy as np

a = np.array([[1,2],
              [3,4]])

b = np.array([[5,6],
              [7,8]])

print(np.dot(a,b))

# %%
#12 Use Pandas to load a CSV file and display its first 5 rowsA

import pandas as pd

df = pd.read_csv("data.csv")
print(df.head())

# %%
#13 Create a 3D scatter plot using Plotly.
import plotly.express as px

df = px.data.iris()

fig = px.scatter_3d(df, x="sepal_width", y="sepal_length", z="petal_width")
fig.show()
